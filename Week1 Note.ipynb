# %% [markdown]
# # The Hello World of Deep Learning with Neural Networks
# Like every first app you should start with something super simple that shows the overall scaffolding for how your code works.
#
# In the case of creating neural networks, the sample I like to use is one where it learns the relationship between two numbers. So, for example, if you were writing code for a function like this, you already know the 'rules' —
#
# float hw_function(float x){
#     float y = (2 * x) - 1;
#     return y;
# }
# So how would you train a neural network to do the equivalent task? Using data! By feeding it with a set of Xs, and a set of Ys, it should be able to figure out the relationship between them.
#
# This is obviously a very different paradigm than what you might be used to, so let's step through it piece by piece.

# %%
import tensorflow as tf 
import numpy as np
from tensorflow import keras

# %%
model  = keras.Sequential([keras.layers.Dense(units = 1, input_shape = [1])])  # 모델 생성

model.compile(optimizer = 'sgd', loss = 'mean_squared_error') # 모델이 얼마나 정확한지 알려주는 코드


xs = np.array([-1.0,0.0,1.0,2.0,3.0,4.0],dtype =float)
ys = np.array([-3.0,-1.0,1.0,3.0,5.0,7.0])

model.fit(xs,ys, epochs = 500) 
# 얼마나 잘되는지 예측 loss가 그 역할을 함.
# 정확한 값들을 넣어주었기 때문에 비교가 가능함.
# Out:
# Epoch 1/500
# 1/1 [==============================] - 1s 1s/step - loss: 1.0463
# Epoch 2/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.9512
# Epoch 3/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.8738
# Epoch 4/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.8103
# Epoch 5/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.7578
# Epoch 6/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.7141
# Epoch 7/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.6772
# Epoch 8/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.6459
# Epoch 9/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.6189
# Epoch 10/500
# 1/1 [==============================] - 0s 1000us/step - loss: 0.5954
# Epoch 11/500
# 1/1 [==============================] - 0s 1000us/step - loss: 0.5746
# Epoch 12/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.5561
# ...

# %%
print(model.predict([10,0]))

# 진짜 값은 19이나 19에 굉장히 근접한 값으로 나옴
# 이유는 굉장히 적은 갯수의 데이터 수로 인해서 저 숫자외의 값들이 100% 확률로 저 배열을 따를 것이라 확실하지
# 못하기 때문.
# Out:
# [[18.986593 ]
#  [-0.9939753]]
